# %% [markdown]
# ## Custom train

# %%
# !unzip -qq "/content/dataset.zip"

# %%
# %cd /content/
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/dataset/data.yaml

# %%
# %cd /
from glob import glob

img_list = glob('/content/dataset/train/images/*.jpg')

print(len(img_list))

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size = 0.2, random_state=150)
print(len(train_img_list), len(val_img_list))

# %%
with open('/content/dataset/train.txt', 'w') as f:
  f.write('\n'.join(train_img_list) + '\n')
with open('/content/dataset/val.txt', 'w') as f:
  f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml

with open('/content/dataset/data.yaml', 'r') as f:
  data = yaml.full_load(f)

print(data)

data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'

with open('/content/dataset/data.yaml', 'w') as f:
  yaml.dump(data, f)
print(data)

# %%
# %cd /content/yolov5/

# !python train.py --img 416 --batch 16 --epochs 25 --data /content/dataset/data.yaml --cfg ./models/yolov5m.yaml --weights yolov5m.pt --name eyes_yolov5m_results

# %%
from IPython.display import Image
import os

# !python detect.py --weights /content/yolov5/runs/train/eyes_yolov5m_results/weights/best.pt --source "/content/dataset/test9.png"
